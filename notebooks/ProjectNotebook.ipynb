# %%
import yfinance as yf
import os
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Check if the data is already downloaded
DATA_PATH = "./input/msft_data.json"

if os.path.exists(DATA_PATH):
    # Read the data if it is already downloaded
    with open(DATA_PATH) as f:
        msft_hist = pd.read_json(DATA_PATH)
else:
    msft = yf.Ticker("MSFT")
    msft_hist = msft.history(period = "max")

    # Save the data in a json file
    msft_hist.to_json(DATA_PATH)

# %%
# Show the first 5 rows of the data
msft_hist.head(5)
# Out:
#                          Open      High       Low     Close      Volume  \
# 1986-03-13 05:00:00  0.055241  0.063365  0.055241  0.060657  1031788800
# 1986-03-14 05:00:00  0.060657  0.063907  0.060657  0.062823   308160000
# 1986-03-17 05:00:00  0.062823  0.064448  0.062823  0.063907   133171200
# 1986-03-18 05:00:00  0.063907  0.064448  0.061740  0.062281    67766400
# 1986-03-19 05:00:00  0.062281  0.062823  0.060657  0.061198    47894400
#
#                      Dividends  Stock Splits
# 1986-03-13 05:00:00        0.0           0.0
# 1986-03-14 05:00:00        0.0           0.0
# 1986-03-17 05:00:00        0.0           0.0
# 1986-03-18 05:00:00        0.0           0.0
# 1986-03-19 05:00:00        0.0           0.0

# %%
# Plot the stock prices
msft_hist.plot.line(y="Close", use_index=True)
# Out:
# <Axes: >

# %%
# Save the actual closing data
data = msft_hist[["Close"]]
data = data.rename(columns = {'Close': 'Actual_Close'})

# Save in target if the price went up or down
data["Target"] = msft_hist.rolling(2).apply(lambda x: x.iloc[1] > x.iloc[0])["Close"]

# %%
data.head()
# Out:
#                      Actual_Close  Target
# 1986-03-13 05:00:00      0.060657     NaN
# 1986-03-14 05:00:00      0.062823     1.0
# 1986-03-17 05:00:00      0.063907     1.0
# 1986-03-18 05:00:00      0.062281     0.0
# 1986-03-19 05:00:00      0.061198     0.0

# %%
# shift stock prices one day, to predict tomorrow's prices whith today's prices
msft_prev = msft_hist.copy()
msft_prev = msft_prev.shift(1)

# %%
msft_prev.head()
# Out:
#                          Open      High       Low     Close        Volume  \
# 1986-03-13 05:00:00       NaN       NaN       NaN       NaN           NaN
# 1986-03-14 05:00:00  0.055241  0.063365  0.055241  0.060657  1.031789e+09
# 1986-03-17 05:00:00  0.060657  0.063907  0.060657  0.062823  3.081600e+08
# 1986-03-18 05:00:00  0.062823  0.064448  0.062823  0.063907  1.331712e+08
# 1986-03-19 05:00:00  0.063907  0.064448  0.061740  0.062281  6.776640e+07
#
#                      Dividends  Stock Splits
# 1986-03-13 05:00:00        NaN           NaN
# 1986-03-14 05:00:00        0.0           0.0
# 1986-03-17 05:00:00        0.0           0.0
# 1986-03-18 05:00:00        0.0           0.0
# 1986-03-19 05:00:00        0.0           0.0

# %%
# Create training data
predictors = ["Close", "Volume", "Open", "High", "Low"]
data = data.join(msft_prev[predictors]).iloc[1:]

# %%
data.head()
# Out:
#                      Actual_Close  Target     Close        Volume      Open  \
# 1986-03-14 05:00:00      0.062823     1.0  0.060657  1.031789e+09  0.055241
# 1986-03-17 05:00:00      0.063907     1.0  0.062823  3.081600e+08  0.060657
# 1986-03-18 05:00:00      0.062281     0.0  0.063907  1.331712e+08  0.062823
# 1986-03-19 05:00:00      0.061198     0.0  0.062281  6.776640e+07  0.063907
# 1986-03-20 05:00:00      0.059574     0.0  0.061198  4.789440e+07  0.062281
#
#                          High       Low
# 1986-03-14 05:00:00  0.063365  0.055241
# 1986-03-17 05:00:00  0.063907  0.060657
# 1986-03-18 05:00:00  0.064448  0.062823
# 1986-03-19 05:00:00  0.064448  0.061740
# 1986-03-20 05:00:00  0.062823  0.060657

# %%
# Create a random forest classification model
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

# %%
# Create train and test set
train = data.iloc[:-100]
test = data.iloc[-100:]

model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

# Assess the error of predictions 
preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds)
# Out:
# 0.5076923076923077

# %%
# Plot Target and Target prediction
combined = pd.concat({"Target": test["Target"], "Predictions": preds}, axis=1)
combined.plot()
# Out:
# <Axes: >

# %%
# Count Ups and Downs on the stock price predictions
combined["Predictions"].value_counts()
# Out:
# 0.0    484
# 1.0     16
# Name: Predictions, dtype: int64

# %%
# Predict using the raw probabilities and decreasing false positives to improve precision
preds = model.predict_proba(test[predictors])[:,1]
preds = pd.Series(preds, index=test.index)
preds[preds > .6] = 1
preds[preds <= .6] = 0

# Assest the error of the predictions
precision_score(test["Target"], preds)
# Out:
# 0.5

# %%
# Plot Target and Target prediction
combined = pd.concat({"Target": test["Target"], "Predictions": preds}, axis=1)
combined.plot()
# Out:
# <Axes: >

# %%
# Count Ups and Downs on the stock price predictions
combined["Predictions"].value_counts()
# Out:
# 0.0    498
# 1.0      2
# Name: Predictions, dtype: int64

# %%
from sklearn.model_selection import TimeSeriesSplit

# Use time series cross validation to deal with bias and variance
tscv = TimeSeriesSplit(n_splits=6)
predictions = []

for train_index, test_index in tscv.split(data):

    train_data = data.iloc[train_index]
    test_data = data.iloc[test_index]

    X_train = train_data[predictors]
    y_train = train_data["Target"]
    X_test = test_data[predictors]
    y_test = test_data["Target"]

    model.fit(X_train, y_train)

    preds = model.predict_proba(X_test)[:,1] 
    preds = pd.Series(preds, index=y_test.index)
    preds[preds > .6] = 1
    preds[preds <= .6] = 0

    combined = pd.concat({"Target" : y_test, "Predictions": preds}, axis =1)

    predictions.append(combined)

predics = pd.concat(predictions)

predics["Predictions"].value_counts()
# Out:
# 0.0    6579
# 1.0    1419
# Name: Predictions, dtype: int64

# %%
precision_score(predics["Target"], predics["Predictions"])
# Out:
# 0.5405214940098662
